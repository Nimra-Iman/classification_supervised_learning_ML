# %%
information gain is baised towards those features that have more unique values, yani column having more unique values, to us
ka information gain ziada ata ha and usi ko hi y spitting k liye final krta ,,, hala k vo column splitting k liye bilkul
acha nhi tha q k y data ko evenly distribuite nhi kr rha , which raise problem

--> is liye hm gain ratio ko use krty hn instead of information gain because GAIN RATIO sirf y nhi dekhta k kitni information
mil rhi us column s bal k y bhi dekhta k how evenly the data is suplitted by this feature, to y INFORMATION GAIN ko ek
term called as 'SPLIT INFORMATION' us s divide krta

# %%
GAIN RATIO  = information gain / split information

# %%
agr feature m unique values ziada hn to because of its high gain y vala feature select ho jay ga
and this featrure will split the data into many tiny small pieces , and this is reason k
split information bhi ziada ho jay gi and gian ratio thori ho jay gi or hmy gain ko ziada krna h kisi feature ko splitting 
k liye select krny k liye , yani gain ratio sirf biased nhi hoti kisi ek feature pr
q k y chahti h k vo feature select ho jo na sirf information ziada de bal k data ko split bhi meaning full
way m kry,,,, isi trah s y overfitting ko bhi km krti
