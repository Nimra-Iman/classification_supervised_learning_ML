# %%
from IPython.display import Image
Image(filename='1.png', width=300, height=300)

# %%
from IPython.display import Image
Image(filename='2.jpeg', width=300, height=300)

# %%
from IPython.display import Image
Image(filename='3.jpeg', width=300, height=300)

# %%
from IPython.display import Image
Image(filename='4.jpeg', width=300, height=300)

# %%
from IPython.display import Image
Image(filename='5.png', width=300, height=300)

# %%
from IPython.display import Image
Image(filename='6.jpeg', width=300, height=300)

# %%
from IPython.display import Image
Image(filename='7.jpeg', width=300, height=300)
