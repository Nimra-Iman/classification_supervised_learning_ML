# %%
sometimes , our model are rejected despiote 98% accuracy or higher, and only reason behind it is 
confusion matrix/evaluation matrix/error matrix

# %%
it is actually made between the predicted output and actual output.

# %%
from IPython.display import Image
Image(filename='confusion_matrix_pic.png', width=300, height=300)

# %%
y jo uper TN, TP etc k agy kuch diits likhy huy hn y y hn k jab test kia gya model ka or total 
attempts m TN 86 ay and FP 7 ay etc etc

# %% [markdown]
# <h1> how our model is rejected despite good accuracy only due to error matrix ???</h1>

# %%
most dangerous error k jb hmary pas FN ki condition ay yani is person ko cancer tha actually or model
m kha k nhi h or vo person n koi medication nhi li or vo mer gya,,,  
---> to jb bhi hm n model ko test kia man lo k 100 data points pr hm n model ko test kia or accuarcy 95% ai, jis m 
50% TP aya and 45% TN aya or baki jo 5% aya vo FN m aya and 0% FP m aya, ab yha poora ka poora 5% hi FN m aya to model
reject ho gay ga q k FN is very dangerous.

----> this is for cancer where FN (type II) error in dangeroeus , but in other scenerios may be FP(type I) error is
more dangerous but it is true the despote 95% accuracy or 98% accuracy, our model is rejected dua to confusion matrix.


----> consider a scenerio where your model differ between spam and not_spam emails , yhan emial spam thi us n kha k spam
nhi h or not_spam m daa di yani FN to y koi bra msla nhi lekin agar esa ho k emial spam nhi thi bal k ek important
business mail thi or model n bola k y spam h yani FP to y k bhhttt bra msla h, yani yha FP yani type I error is more
dangerous, such as consider below:

# %%
from IPython.display import Image
Image(filename='confusion_mat.png', width=300, height=300)
# ab yhan B ko select kia due to low type I errro
