# %%
in this , we train our 2 to 3 models simultaneously on our dataset and get accuracy that is a combination
of these models.

# %%
from IPython.display import Image
Image(filename='techniques.png', width=400, height=300)

# %%
bagging and boosting are most important and most popular these days
